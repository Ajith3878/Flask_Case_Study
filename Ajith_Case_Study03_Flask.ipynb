# %% [markdown]
# Case Study on Python Flask: Using the given dataset, create a web application to take feature inputs from the user in a web page and print whether a person will purchase the product or not.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/Social_Network_Ads (3).csv')
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
#Encoding of Object Data
import sklearn.preprocessing as sk

obj_data = df.select_dtypes(include = 'object')
le = sk.LabelEncoder()
for i in obj_data:
    df[i] = le.fit_transform(df[i])

# %%
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510       1   19            19000          0
# 1    15810944       1   35            20000          0
# 2    15668575       0   26            43000          0
# 3    15603246       0   27            57000          0
# 4    15804002       1   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863       0   46            41000          1
# 396  15706071       1   51            23000          1
# 397  15654296       0   50            20000          1
# 398  15755018       1   36            33000          0
# 399  15594041       0   49            36000          1
#
# [400 rows x 5 columns]

# %%
df = df.drop('User ID',axis=1)

# %%
df
# Out:
#      Gender  Age  EstimatedSalary  Purchased
# 0         1   19            19000          0
# 1         1   35            20000          0
# 2         0   26            43000          0
# 3         0   27            57000          0
# 4         1   19            76000          0
# ..      ...  ...              ...        ...
# 395       0   46            41000          1
# 396       1   51            23000          1
# 397       0   50            20000          1
# 398       1   36            33000          0
# 399       0   49            36000          1
#
# [400 rows x 4 columns]

# %%
x=df.drop(['Purchased'],axis=1)
y=df['Purchased']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=42,test_size=0.25)

# %%
from sklearn import linear_model
lr = linear_model.LinearRegression()

# %%
model=lr.fit(x_train,y_train)

# %%
predict=model.predict(x_test)

# %%
predict
# Out:
# array([ 3.64166451e-01,  9.68738776e-01, -4.81112016e-03,  7.20774412e-01,
#        -4.53242706e-02,  1.20593834e-01,  7.40644437e-01,  1.81750110e-01,
#         4.35282331e-01,  4.45085782e-01,  2.60703966e-01,  5.92523912e-01,
#        -1.16020876e-01, -2.95871058e-01,  2.29377319e-01,  4.43802703e-01,
#         5.83493561e-01,  5.78854957e-01,  2.73492851e-01,  7.82070575e-01,
#        -2.28266855e-01,  1.74932092e-01,  3.99407784e-01,  9.19195274e-01,
#        -3.32362553e-01,  5.01587190e-01,  5.07015159e-01,  2.67818024e-01,
#         1.01931850e+00, -3.29673160e-01,  4.42610328e-01, -1.21802672e-01,
#         6.17978058e-01,  1.45258615e-01,  5.67398334e-01,  3.07558074e-01,
#         2.76075275e-01,  3.37338520e-01, -1.08133718e-01, -1.61172631e-01,
#         4.66238887e-01, -6.15756493e-02, -2.21662776e-01,  3.87021909e-01,
#        -1.82958948e-01,  7.96125886e-01,  9.64882147e-02,  1.83296312e-01,
#         4.99267888e-01,  1.44329363e-01,  6.86240614e-02,  7.90697917e-01,
#         2.96052269e-01,  7.27526865e-02,  3.73723046e-01, -8.40280979e-02,
#         1.05765224e+00,  2.49617435e-01,  2.01250044e-01,  2.09507294e-01,
#         3.56172323e-01,  2.27674966e-01,  7.98182067e-01,  1.72719760e-01,
#         6.26861132e-02,  3.53606164e-01,  5.42733553e-01,  8.93403566e-01,
#         3.38111621e-01,  4.07788269e-01,  9.96356072e-01, -5.98732959e-02,
